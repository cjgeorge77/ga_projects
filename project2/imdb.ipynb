# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv',encoding ='utf-8')
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
#movies.sort_values('duration',ascending=False)
#movies.sort_values('duration')

movie_long=movies.title.loc[movies.duration.idxmax()]
movie_short=movies.title.loc[movies.duration.idxmin()]
print("shortest duration movie: "+ movie_short)
print("longest duration movie: "+ movie_long)
# Out:
# shortest duration movie: Freaks
# longest duration movie: Hamlet

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.duration.hist(bins=10)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
plt.boxplot(movies.duration);

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.content_rating.value_counts(dropna=False)
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# NaN            3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.content_rating.value_counts(dropna=False).plot(kind="bar")

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies.content_rating.replace('NOT RATED', 'UNRATED',inplace=True)
movies.content_rating.replace('APPROVED', 'UNRATED',inplace=True)
movies.content_rating.replace('PASSED', 'UNRATED',inplace=True)
movies.content_rating.replace('GP', 'UNRATED',inplace=True)

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies.content_rating.replace('X', 'NC-17',inplace=True)
movies.content_rating.replace('TV-MA', 'NC-17',inplace=True)

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
print(movies.isnull().sum())
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies.content_rating.fillna(value='UNRATED',inplace=True)

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
short_mov = movies[(movies.duration < 120)]
avg_mov = []
avg_mov.append(short_mov.star_rating.mean())
long_mov = movies[(movies.duration > 120)]
avg_mov.append(long_mov.star_rating.mean())
print(avg_mov)
# Out:
# [7.838666666666657, 7.953669724770622]

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
movies.corr()
# Out:
#              star_rating  duration
# star_rating     1.000000  0.227149
# duration        0.227149  1.000000

# %%
# Answer:
movies.plot(kind='scatter', x='duration', y='star_rating')

print((movies.corr()['star_rating'])) 
print("There is very less correlation between duration and star_rating")
# Out:
# star_rating    1.000000
# duration       0.227149
# Name: star_rating, dtype: float64
# There is very less correlation between duration and star_rating

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby("genre").duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.groupby("content_rating").duration.mean().plot(kind='bar')

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.groupby('genre')["title",'star_rating'].max()
# Out:
#                                          title  star_rating
# genre
# Action                                 Yojimbo          9.0
# Adventure                            True Grit          8.9
# Animation                       Wreck-It Ralph          8.6
# Biography                        Walk the Line          8.9
# Comedy                              Zombieland          8.6
# Crime                                   Zodiac          9.3
# Drama                                     Zulu          8.9
# Family     Willy Wonka & the Chocolate Factory          7.9
# Fantasy              The City of Lost Children          7.7
# Film-Noir                        The Third Man          8.3
# History                    Battleship Potemkin          8.0
# Horror                                   [Rec]          8.6
# Mystery                                Vertigo          8.6
# Sci-Fi           The Day the Earth Stood Still          8.2
# Thriller             The Man Who Knew Too Much          8.0
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
#movies[movies.duplicated('title')]
pd.concat(g for _, g in movies.groupby("title") if len(g) > 1)
# Out:
#      star_rating                            title content_rating      genre  \
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 678          7.7                   Les Miserables          PG-13      Drama
# 924          7.5                   Les Miserables          PG-13      Crime
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 936          7.4                        True Grit        UNRATED  Adventure
#
#      duration                                        actors_list
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 678       158  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
movies2 = movies[movies.genre.isin(["Drama","Comedy","Action","Crime","Biography","Adventure","Animation","Horror","Mystery"])]
movies2
movies2.groupby('genre')["title",'star_rating'].mean()
# Out:
#            star_rating
# genre
# Action        7.884559
# Adventure     7.933333
# Animation     7.914516
# Biography     7.862338
# Comedy        7.822436
# Crime         7.916935
# Drama         7.902518
# Horror        7.806897
# Mystery       7.975000

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
movies["actor_refined"] = movies.actors_list.apply(eval)

# %%
#movies["n_actor"] = len(movies["actor_refined"])
# Out:
# 979

# %%
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...
